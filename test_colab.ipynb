# %% [markdown]
# # AUD 613 - Colab Test
# If you can see this in Google Colab, the GitHub-to-Colab pipeline works!

# %%
import numpy as np
print('Hello from AUD 613!')
print(f'NumPy version: {np.__version__}')
